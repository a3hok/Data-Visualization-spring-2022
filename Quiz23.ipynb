# %% [markdown]
# <a href="https://colab.research.google.com/github/a3hok/Data-Visualization-spring-2022/blob/main/Quiz23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Find two charts that were not discussed during class today and examine them for graphical excellence, sophistication and integrity. You should write about 100 words about each graph and include the image and a link to where it can be found.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The link for the image is https://math.scholastic.com/issues/2017-18/092517/fake-news-fake-data.html#1120L
#
# In the above pie chart, we can see how the use of a pie chart was clearly  the bad reprensation of the data. Pie charts depict pieces of a whole where the total value equals 100 percent. This is basic mathematical understanding. The total of the elements in the figure above, however, equals 139 percent, which is theoretically impossible to depict using a pie chart.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The link for the image is https://towardsdatascience.com/why-is-this-chart-bad-5f16da298afa
#
#
# The above pie chart is is a type of poll that attempts to determine the popularity of a given game based on which one is the most popular. However, there are two types of issues with the visualization. To begin with, it has far too many variables, making it complicated. Second, the various colors employed are difficult to distinguish from one another, making it difficult for observers to distinguish the region covered by each of the games.
