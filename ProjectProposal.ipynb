# %% [markdown]
# <a href="https://colab.research.google.com/github/a3hok/Data-Visualization-spring-2022/blob/main/ProjectProposal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Best Team in Indian Premier league(IPL)**
#
#
#
# **Ashok Dahal**
#
# **East Central University**
#
# **Spring 2022**
#
# **CPSMA 4313**
#
# **Professor Dr. Nicholas Jacob**
#
#
# > **Abstract**:
# The Indian Premier League (IPL) is a professional Twenty20 cricket league in India that takes place in April and May each year and features teams from various Indian cities and states. The BCCI (Board of Control for Cricket in India) established the league in 2008. The IPL is the most popular cricket league in the world, ranking sixth among all sports leagues in terms of average attendance in 2014. The IPL tournament has lasted 10 seasons.The following data are from 2008 - 2017
#
# <img src='https://www.kaggleusercontent.com/kf/756143/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2In0..KydXQJLDyNsK6MH2aQaSzA.AFZ74FC8cnUb2tRyFpM7sqBzebzsTom21ha1qLS3d0S8_dwU_de03F22Nh-4QVC_SxEhUSm70XmzVQaXZvaHVt6XQwyVRx8FCZtk2FWlGk19U5_X5f_wUBgeNFKMVnDXi4sbJpyQBuWBeRti7GVzDTCoEi-XmePfRxWG9Sdj4q5blBDeNR2mFWk3xGL4w6A5MVcOBcLqA8dth59IqaA95ep2ByyPU-OSym8HTrR3ELD-e84-1MljfZ_Y5BcVVKcjq_TXal34hFw_7Dec0kPMZeNSqC5mEr8Z7rTthB-Ji9e18iL_MTa5hUsXml5oOp2q34wZVIXSDdcDgvwbWhDUUw4bYJeMdNpGystm-EIjpWLaI5ZNIJS6yCu9qljJEFbQFhSM29lf7aNqM1CKMCWm82wlECJCsAezdUQU3l716JJ1_62TSkVJF-9H6eC2X8dIAuGxlb0htFFBLTD80c8YB-k9TE7wI6RaUuKd5nHMR8LhyklPbov-eGDOdsNyaIznz0KFGLmQUz2JapD7N283LYZWnpAM8auGXKPJwJWZk-l1KD_Uv1uWjSZQNYVlcNHFaWnMKkLSL62oet1C34RSFiP2_iXkcW_9vhBewT0M3WGAjKZA8eLj2tSFMoA83o3QafiJuUrIDE-RwT4pBOi9oNyeOwhuqRwh-M4tF-g3PikUmEtxfXij3vOl8Dg8566S.-Bdim7ZrKLBhm1aZjzFjCA/__results___files/__results___20_1.png'>
#
#
#
#
#
#
# The link for above graph:-

# %% [markdown]
# https://www.kaggle.com/code/nirajvermafcb/data-visualisation-for-ipl-datasets-1/notebook

# %% [markdown]
# ![Screen Shot 2022-04-24 at 6.28.37 PM.png](data:image/png;base64,...)

# %% [markdown]
# The link for the above chart is:_
# https://public.tableau.com/app/profile/harsh3655/viz/IndianPremierLeagueDataAnalysisDashboardsProject1/Dashboard1

# %% [markdown]
# ![Screen Shot 2022-04-24 at 8.16.59 PM.png](data:image/png;base64,...)

# %% [markdown]
# The link for above data
# https://public.tableau.com/app/profile/pratham.agarwala/viz/IPLbestplayers/Story1

# %% [markdown]
# In my opinion all the chart are Excellent Graph. All the information have a clarity and we can easilly understand.
# I presented the graph from screenshot from the browser but with the screeenshot also  we can still examine it for graphical excellence.
# The first and second are differnt but it shows same information. By looking we can easilly compare the best team in the IPL. The name of the team are in shortcut it can makes little bit confusing if you never watched IPL.
# Overall the third graph is an excellent graphic too. It tells the average batsman runs, economy of the bowler as well as man of the match of the IPL.

# %% [markdown]
# #conclusion
# In conclusion, visualization of recent trend of a soprts tournament IPL interested for me. It is one of game I have been watching . In this project I have presented with total of three graphs that shows  same kinds of information in a different ways. We can understand the same data that have different visualization. Data visualization is critical, and using appropriate graphical brilliance makes it crystal evident.
