# %% [markdown]
# <a href="https://colab.research.google.com/github/a3hok/Data-Visualization-spring-2022/blob/main/Recreating%20the%20Master.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Death From Coronavirus**
#
#
#
# **Ashok Dahal**
#
# **East Central University**
#
# **Spring 2022**
#
# **CPSMA 4313**
#
# **Professor Dr. Nicholas Jacob**
#
#
# > **Abstract**:
# Recreating the masters in the total teath from coronavirus.The 2019–20 coronavirus pandemic is a worldwide coronavirus disease 2019 (COVID-19) pandemic caused by the coronavirus 2 that causes severe acute respiratory illness (SARS-CoV-2). In December, the virus initially appeared in Wuhan, Hubei, China. Many cases have been verified in over 110 countries and territories.

# %% [markdown]
# ![coronavirus-data-explorer.png](data:image/png;base64,...)

# %% [markdown]
# The Visualization that I am creating can be found in https://ourworldindata.org/covid-deaths

# %% [markdown]
# The link for my Datasets https://github.com/a3hok/Data-Visualization-spring-2022/blob/main/covid.csv

# %% [markdown]
# I am going to recreate the graph because till now the corona Virus which was started on 2019 from mainland china still out of control and spread around the world. I would like to visulaize how the coronavirus has changes the ways of living and how many causaulties it has done around the world.
#
#
#
# The above graphs are Visualization Excellence as it clearly shows the total number of death of five main countrie around the world.

# %% [markdown]
# I think I may get some difficulties while creating this because all the data and the inforrmation are not easilly avaiable. I try to make it clear to visual with perfect colour as well.
